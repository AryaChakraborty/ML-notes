# %%
import requests
import pandas as pd

# %%
final = pd.DataFrame()

# %%
for j in range(1, 31) :
    
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(j)).json()
    
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_date = []

    for i in response['results'] :
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])

    diction = {'popularity' : popularity, 'vote_count' : vote_count, 'original_language' : original_language, 'title' : title,
               'vote_average' : vote_average, 'overview' : overview, 'release_date' : release_date}

    data = pd.DataFrame(diction)
    
    final = final.append(data, ignore_index = True)

# %%
final
# Out:
#      popularity  vote_count original_language  \
# 0     11308.998         714                en
# 1      8887.435        1569                en
# 2     12394.971        1052                en
# 3      7821.905        1046                en
# 4      3992.478        1789                en
# ..          ...         ...               ...
# 595     118.428         131                tr
# 596     129.103          14                es
# 597     108.990        1185                en
# 598     101.261        5606                en
# 599     115.219         514                en
#
#                                            title  vote_average  \
# 0                                  The Lost City           6.8
# 1                           Sonic the Hedgehog 2           7.7
# 2                                        Morbius           6.4
# 3                                   The Northman           7.5
# 4    Doctor Strange in the Multiverse of Madness           7.4
# ..                                           ...           ...
# 595                                 Love Tactics           6.8
# 596                    Cuidado con lo que deseas           4.8
# 597         Escape Room: Tournament of Champions           6.7
# 598                                       Tarzan           7.4
# 599                                     Voyagers           6.1
#
#                                               overview release_date
# 0    A reclusive romance novelist was sure nothing ...   2022-03-24
# 1    After settling in Green Hills, Sonic is eager ...   2022-03-30
# 2    Dangerously ill with a rare blood disorder, an...   2022-03-30
# 3    Prince Amleth is on the verge of becoming a ma...   2022-04-07
# 4    Doctor Strange, with the help of mystical alli...   2022-05-04
# ..                                                 ...          ...
# 595  An ad executive and a fashion designer-blogger...   2022-02-11
# 596                                                      2021-11-12
# 597  Six people unwittingly find themselves locked ...   2021-07-01
# 598  Tarzan was a small orphan who was raised by an...   1999-06-18
# 599  With the future of the human race at stake, a ...   2021-04-08
#
# [600 rows x 7 columns]
